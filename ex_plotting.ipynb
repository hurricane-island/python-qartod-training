# %%
import pandas as pd
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
from matplotlib import ticker
import matplotlib.dates as mdates

file_path = '/Users/adelejordan/Downloads/Wynken_SondeValues_Cleaned_2025-05-14T22-45.csv'
cleaned_df = pd.read_csv(file_path, header=0)
print(cleaned_df.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 40
#      36 ax.xaxis.set_major_formatter(mdates.DateFormatter('%d %b %y'))
#      39 timestamp = df['TIMESTAMP']
# ---> 40 external_temp = float(df['External_Temp'].values)
#      43 #ax.plot(timestamp, external_temp)
#      44 #plt.show()
#      45 #print(external_temp)
#      47 plt.plot(timestamp, external_temp)
#
# TypeError: only length-1 arrays can be converted to Python scalars
